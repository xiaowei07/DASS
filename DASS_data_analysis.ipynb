# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('data.csv',sep='\t')

# %%
data.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  screensize  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...           1
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...           2
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...           2
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...           2
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...           2
#
#    uniquenetworklocation  hand  religion  orientation  race  voted  married  \
# 0                      1     1        12            1    10      2        1
# 1                      1     2         7            0    70      2        1
# 2                      1     1         4            3    60      1        1
# 3                      1     2         4            5    70      2        1
# 4                      2     3        10            1    10      2        1
#
#    familysize       major
# 0           2         NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39775 entries, 0 to 39774
# Columns: 172 entries, Q1A to major
# dtypes: int64(170), object(2)
# memory usage: 52.2+ MB

# %%
data.isnull().sum()
# Out:
# Q1A                           0
# Q1I                           0
# Q1E                           0
# Q2A                           0
# Q2I                           0
# Q2E                           0
# Q3A                           0
# Q3I                           0
# Q3E                           0
# Q4A                           0
# Q4I                           0
# Q4E                           0
# Q5A                           0
# Q5I                           0
# Q5E                           0
# Q6A                           0
# Q6I                           0
# Q6E                           0
# Q7A                           0
# Q7I                           0
# Q7E                           0
# Q8A                           0
# Q8I                           0
# Q8E                           0
# Q9A                           0
# Q9I                           0
# Q9E                           0
# Q10A                          0
# Q10I                          0
# ...

# %%
np.array(data.columns)
# Out:
# array(['Q1A', 'Q1I', 'Q1E', 'Q2A', 'Q2I', 'Q2E', 'Q3A', 'Q3I', 'Q3E',
#        'Q4A', 'Q4I', 'Q4E', 'Q5A', 'Q5I', 'Q5E', 'Q6A', 'Q6I', 'Q6E',
#        'Q7A', 'Q7I', 'Q7E', 'Q8A', 'Q8I', 'Q8E', 'Q9A', 'Q9I', 'Q9E',
#        'Q10A', 'Q10I', 'Q10E', 'Q11A', 'Q11I', 'Q11E', 'Q12A', 'Q12I',
#        'Q12E', 'Q13A', 'Q13I', 'Q13E', 'Q14A', 'Q14I', 'Q14E', 'Q15A',
#        'Q15I', 'Q15E', 'Q16A', 'Q16I', 'Q16E', 'Q17A', 'Q17I', 'Q17E',
#        'Q18A', 'Q18I', 'Q18E', 'Q19A', 'Q19I', 'Q19E', 'Q20A', 'Q20I',
#        'Q20E', 'Q21A', 'Q21I', 'Q21E', 'Q22A', 'Q22I', 'Q22E', 'Q23A',
#        'Q23I', 'Q23E', 'Q24A', 'Q24I', 'Q24E', 'Q25A', 'Q25I', 'Q25E',
#        'Q26A', 'Q26I', 'Q26E', 'Q27A', 'Q27I', 'Q27E', 'Q28A', 'Q28I',
#        'Q28E', 'Q29A', 'Q29I', 'Q29E', 'Q30A', 'Q30I', 'Q30E', 'Q31A',
#        'Q31I', 'Q31E', 'Q32A', 'Q32I', 'Q32E', 'Q33A', 'Q33I', 'Q33E',
#        'Q34A', 'Q34I', 'Q34E', 'Q35A', 'Q35I', 'Q35E', 'Q36A', 'Q36I',
# ...

# %% [markdown]
# ## Demographic Informations

# %%
data['country'].unique()
# Out:
# array(['IN', 'US', 'PL', 'MY', 'MX', 'GB', 'DE', 'EE', 'CA', 'EC', 'AU',
#        'FI', 'ID', 'AE', 'NONE', 'ES', 'NI', 'DO', 'TR', 'NO', 'GR', 'LK',
#        'BR', 'AR', 'KH', 'IT', 'MK', 'PT', 'BA', 'RU', 'HU', 'KR', 'IE',
#        'RS', 'CZ', 'PH', 'RO', 'FR', 'SG', 'AT', 'UA', 'KW', 'CO', 'GE',
#        'SE', 'HK', 'NZ', 'ZA', 'NL', 'DK', 'JM', 'LB', 'CL', 'AW', 'IL',
#        'GT', 'PE', 'PK', 'NP', 'HR', 'CR', 'VE', 'BG', 'GH', 'MA', 'PR',
#        'SI', 'LV', 'AL', 'VN', 'GU', 'BD', 'TH', 'NG', 'FO', 'UY', 'EG',
#        'BE', 'SA', 'SV', 'CH', 'PY', 'SK', 'SY', 'TN', 'TT', 'SR', 'KE',
#        'BY', 'PA', 'CY', 'BW', 'MZ', 'BB', 'GG', 'CW', 'IS', 'IR', 'BN',
#        'MV', 'OM', 'DZ', 'JP', 'MU', nan, 'IQ', 'BO', 'MD', 'CN', 'LT',
#        'BZ', 'BH', 'ME', 'QA', 'TW', 'PS', 'JO', 'SD', 'KY', 'AZ', 'AO',
#        'BS', 'GY', 'MO', 'TZ', 'IM', 'AF', 'AM', 'UZ', 'LU', 'ET', 'JE',
#        'VU', 'TJ', 'KZ', 'XK', 'HN', 'ZW', 'LA', 'MT', 'SN', 'MN', 'TG',
# ...

# %%
data['country'].value_counts()
# Out:
# MY      21605
# US       8207
# GB       1180
# CA        978
# ID        884
# PH        749
# AU        608
# NONE      539
# IN        446
# DE        314
# SG        292
# NZ        216
# FR        187
# BR        180
# PL        172
# BN        171
# MX        154
# RO        143
# IT        138
# NL        114
# ES         90
# JP         85
# FI         81
# TR         80
# ZA         79
# PK         79
# SE         76
# EG         75
# GR         74
# IE         74
#         ...
# SY          3
# MT          3
# GG          2
# MN          2
# TN          2
# GY          2
# BW          2
# AO          2
# TZ          2
# JE          2
# FO          2
# HN          1
# LA          1
# KY          1
# SN          1
# AF          1
# ZW          1
# SR          1
# TG          1
# CW          1
# RE          1
# TJ          1
# LU          1
# VC          1
# XK          1
# AM          1
# UZ          1
# VU          1
# IM          1
# AW          1
# ...

# %%
ax = sns.countplot(y='source', data=data)
ax.set_yticklabels(["other or unknown", "from the front page of the site hosting the survey", "google"])
# Out:
# [Text(0, 0, 'other or unknown'),
#  Text(0, 0, 'from the front page of the site hosting the survey'),
#  Text(0, 0, 'google')]

# %%
ax = sns.countplot(y='education', data=data)
ax.set_yticklabels(["unknown","less than high school", "high school", "university degree", "graduate degree"])
ax.set_title('Education Level')
plt.show()

# %%
ax = sns.countplot(x='urban', data=data)
ax.set_xticklabels(["unknown","rural","suburban","urban"])
ax.set_title('Urban')
plt.show()

# %%
ax = sns.countplot(x='gender', data=data)
ax.set_xticklabels(["unknown","male","female","other"])
ax.set_title('Gender')
plt.show()

# %%
ax = sns.countplot(x= 'engnat', data=data)
ax.set_xticklabels(["unknown","yes","no"])
ax.set_title('English Native or not')
plt.show()

# %%
# make a mapping
plt.figure(figsize=(20,16))
ax = sns.countplot(x= 'age', data=data)

# %%
data['categorical_age'] = data['age']

# %%
data.loc[ data['categorical_age'] <= 16, 'categorical_age'] = 0
data.loc[(data['categorical_age'] > 16) & (data['categorical_age'] <= 32), 'categorical_age'] = 1
data.loc[(data['categorical_age'] > 32) & (data['categorical_age'] <= 48), 'categorical_age'] = 2
data.loc[(data['categorical_age'] > 48) & (data['categorical_age'] <= 64), 'categorical_age'] = 3
data.loc[ data['categorical_age'] > 64, 'categorical_age'] = 4 ;

# %%
ax = sns.countplot(y='categorical_age',data=data)
ax.set_yticklabels(["Less than 16", "Between 16 and 32","Betwwen 32 and 48", "Between 48 and 64", "Above 64"])
ax.set_title('Adjusted Age Interval')
plt.show()

# %%
ax = sns.countplot(y= 'uniquenetworklocation', data=data)
ax.set_yticklabels(["only one survey from user's specific network in dataset","multiple surveys submitted from the network of this user"])
ax.set_title('Work Location: Survey Submittion')
plt.show()

# %%
ax = sns.countplot(x= 'hand', data=data)
ax.set_xticklabels(["unknown","right","left","both"])
ax.set_title('Hand Preference')
plt.show()

# %%
# note: combine all the christian into one category.
ax = sns.countplot(y= 'religion', data=data)
ax.set_yticklabels(["unknown","Agnostic", "Atheist", "Buddhist", "Christian (Catholic)", "Christian (Mormon)", "Christian (Protestant)", "Christian (Other)", "Hindu", "Jewish", "Muslim", "Sikh", "Other"])
ax.set_title('Religion')
plt.show()

# %%
ax = sns.countplot(y='orientation', data=data)
ax.set_yticklabels(["unknown","heterosexual","bisexual","homosexual","asexual","other"])
ax.set_title('Sexual Orientation')
plt.show()

# %%
ax = sns.countplot(y= 'race', data=data)
ax.set_yticklabels(["Asian", "Arab", "Black", "Indigenous Australian", "Native American","White", "Other"])
ax.set_title('Race')
plt.show()

# %%
ax = sns.countplot(x='voted', data=data)
ax.set_xticklabels(["unknown","yes","no"])
ax.set_title('Vote Status')
plt.show()

# %%
ax = sns.countplot(y= 'married', data=data)
ax.set_yticklabels(["unknown","never married","currently married","previously married"])
ax.set_title('Marriage Status')
plt.show()

# %%
# family size: including you! 
ax = sns.countplot(x= 'familysize', data=data)
ax.set_title('Family Sizes')
plt.show()

# %%
# space and capitalized letter
data['major'].value_counts()
# Out:
# English                                          1026
# Psychology                                        850
# Business                                          621
# Accounting                                        607
# Engineering                                       582
# psychology                                        580
# Law                                               524
# Medicine                                          348
# Science                                           320
# Biology                                           316
# engineering                                       312
# Psychology                                        276
# Education                                         275
# Nursing                                           261
# Computer Science                                  261
# Finance                                           214
# IT                                                208
# ...

# %% [markdown]
# ## Personality Information (TIPIs) Visualization
#
# * TIPI1	Extraverted, enthusiastic.
# * TIPI2	Critical, quarrelsome.
# * TIPI3	Dependable, self-disciplined.
# * TIPI4	Anxious, easily upset.
# * TIPI5	Open to new experiences, complex.
# * TIPI6	Reserved, quiet.
# * TIPI7	Sympathetic, warm.
# * TIPI8	Disorganized, careless.
# * TIPI9	Calm, emotionally stable.
# * TIPI10	Conventional, uncreative.
#
# **With the scale**:
# * 1 = Disagree strongly
# * 2 = Disagree moderately
# * 3 = Disagree a little
# * 4 = Neither agree nor disagree
# * 5 = Agree a little
# * 6 = Agree moderately
# * 7 = Agree strongly

# %%
ax = sns.countplot(x='TIPI1', data=data)
ax.set_title('Extraverted, enthusiastic')
plt.show()

# %%
ax = sns.countplot(x='TIPI2', data=data)
ax.set_title('Critical, quarrelsome')
plt.show()

# %%
ax = sns.countplot(x='TIPI3', data=data)
ax.set_title('Dependable, self-disciplined')
plt.show()

# %%
ax = sns.countplot(x='TIPI4', data=data)
ax.set_title('Anxious, easily upset')
plt.show()

# %%
ax = sns.countplot(x='TIPI5', data=data)
ax.set_title('Open to new experiences, complex')
plt.show()

# %%
ax = sns.countplot(x='TIPI6', data=data)
ax.set_title('Reserved, quiet')
plt.show()

# %%
ax = sns.countplot(x='TIPI7', data=data)
ax.set_title('Sympathetic, warm')
plt.show()

# %%
ax = sns.countplot(x='TIPI8', data=data)
ax.set_title('Disorganized, careless')
plt.show()

# %%
ax = sns.countplot(x='TIPI9', data=data)
ax.set_title('Calm, emotionally stable')
plt.show()

# %%
ax = sns.countplot(x='TIPI10', data=data)
ax.set_title('Conventional, uncreative')
plt.show()

# %% [markdown]
# ## Questions
#
# This response is stored in variable A (e.g. Q1A). Also recorded was the time taken in milliseconds to answer that question (E) and that question's position in the survey (I).

# %% [markdown]
# * Stress: 1,6,8,11,12,14,18,22,27,29,32,33,35,39
# * Anxiety: 2,4,7,9,15,19,20,23,25,28,30,36,40,41
# * Depression: 3,5,10,13,16,17,21,24,26,31,34,37,38,42

# %% [markdown]
# ### Stress
# * Normal: 14 - 28
# * Mild: 29 - 32
# * Moderate: 33 - 39
# * Severe: 40 - 47
# * Extremely Severe: 48 and above

# %%
# 1,6,8,11,12,14,18,22,27,29,32,33,35,39
data['stress_score'] = data.apply(lambda row: row.Q1A + row.Q6A + row.Q8A + row.Q11A + row.Q12A + row.Q14A
                                       + row.Q18A + row.Q22A + row.Q27A + row.Q29A + row.Q32A + row.Q33A + row.Q35A + row.Q39A,
                                       axis=1)

# %%
data.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  hand  religion  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...     1        12
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...     2         7
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...     1         4
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...     2         4
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...     3        10
#
#    orientation  race  voted  married  familysize       major  categorical_age  \
# 0            1    10      2        1           2         NaN                0
# 1            0    70      2        1           4         NaN                0
# 2            3    60      1        1           3         NaN                1
# 3            5    70      2        1           5     biology                0
# 4            1    10      2        1           4  Psychology                1
#
#    stress_score
# 0            54
# ...

# %%
data['stress_category'] = data["stress_score"]

# %%
data.loc[ data['stress_category'] <= 28, 'stress_category'] = 1
data.loc[(data['stress_category'] > 28) & (data['stress_category'] <= 32), 'stress_category'] = 2
data.loc[(data['stress_category'] > 32) & (data['stress_category'] <= 39), 'stress_category'] = 3
data.loc[(data['stress_category'] > 39) & (data['stress_category'] <= 47), 'stress_category'] = 4
data.loc[ data['stress_category'] > 47, 'stress_category'] = 5

# %%
data.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  religion  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...        12
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...         7
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...         4
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...         4
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...        10
#
#    orientation  race  voted  married  familysize       major  categorical_age  \
# 0            1    10      2        1           2         NaN                0
# 1            0    70      2        1           4         NaN                0
# 2            3    60      1        1           3         NaN                1
# 3            5    70      2        1           5     biology                0
# 4            1    10      2        1           4  Psychology                1
#
#    stress_score  stress_category
# 0            54                5
# ...

# %%
ax = sns.countplot(y='stress_category',data=data)
ax.set_yticklabels(['normal','mild','moderate','severe','extremely severe'])
ax.set_title('Stress Level')
plt.show()

# %% [markdown]
# ### Anxiety
#
# * Normal: 14 - 21
# * Mild: 22 - 23
# * Moderate: 24 - 28
# * Severe: 29 - 33
# * Extremely Severe: 34 and above

# %%
# 2,4,7,9,15,19,20,23,25,28,30,36,40,41
data['anxiety_score'] = data.apply(lambda row: row.Q2A + row.Q4A + row.Q7A + row.Q9A + row.Q15A + row.Q19A
                                       + row.Q20A + row.Q23A + row.Q25A + row.Q28A + row.Q30A + row.Q36A + row.Q40A + row.Q41A,
                                       axis=1)

# %%
data['anxiety_category'] = data['anxiety_score']

# %%
data.loc[ data['anxiety_category'] <= 21, 'anxiety_category'] = 1
data.loc[(data['anxiety_category'] > 21) & (data['anxiety_category'] <= 23), 'anxiety_category'] = 2
data.loc[(data['anxiety_category'] > 23) & (data['anxiety_category'] <= 28), 'anxiety_category'] = 3
data.loc[(data['anxiety_category'] > 28) & (data['anxiety_category'] <= 33), 'anxiety_category'] = 4
data.loc[ data['anxiety_category'] > 33, 'anxiety_category'] = 5

# %%
data.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  race  voted  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...    10      2
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...    70      2
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...    60      1
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...    70      2
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...    10      2
#
#    married  familysize       major  categorical_age  stress_score  \
# 0        1           2         NaN                0            54
# 1        1           4         NaN                0            41
# 2        1           3         NaN                1            31
# 3        1           5     biology                0            30
# 4        1           4  Psychology                1            43
#
#    stress_category  anxiety_score  anxiety_category
# 0                5             48                 5
# ...

# %%
ax = sns.countplot(y='anxiety_category',data=data)
ax.set_yticklabels(['normal','mild','moderate','severe','extremely severe'])
ax.set_title('Anxiety Level')
plt.show()

# %% [markdown]
# ### Depression
#
# * Normal: 14 - 23
# * Mild: 24 - 27
# * Moderate: 28 - 34
# * Severe: 35 - 41
# * Extremely Severe: 42 and above

# %%
# 3,5,10,13,16,17,21,24,26,31,34,37,38,42
data['depression_score'] = data.apply(lambda row: row.Q3A + row.Q5A + row.Q10A + row.Q13A + row.Q16A + row.Q17A
                                       + row.Q21A + row.Q24A + row.Q26A + row.Q31A + row.Q34A + row.Q37A + row.Q38A + row.Q42A,
                                       axis=1)

# %%
data['depression_category'] = data['depression_score']

# %%
data.loc[ data['depression_category'] <= 23, 'depression_category'] = 1
data.loc[(data['depression_category'] > 23) & (data['depression_category'] <= 27), 'depression_category'] = 2
data.loc[(data['depression_category'] > 27) & (data['depression_category'] <= 34), 'depression_category'] = 3
data.loc[(data['depression_category'] > 34) & (data['depression_category'] <= 41), 'depression_category'] = 4
data.loc[ data['depression_category'] > 41, 'depression_category'] = 5

# %%
data.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  married  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...        1
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...        1
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...        1
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...        1
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...        1
#
#    familysize       major  categorical_age  stress_score  stress_category  \
# 0           2         NaN                0            54                5
# 1           4         NaN                0            41                4
# 2           3         NaN                1            31                2
# 3           5     biology                0            30                2
# 4           4  Psychology                1            43                4
#
#    anxiety_score  anxiety_category  depression_score  depression_category
# ...

# %%
ax = sns.countplot(y='depression_category',data=data)
ax.set_yticklabels(['normal','mild','moderate','severe','extremely severe'])
ax.set_title('Depression Level')
plt.show()

# %% [markdown]
# ## TIPI Interpretation
#
# * Extroversion: 1, 6R
# * Agreeableness: 2R, 7
# * Conscientiousness: 3, 8R
# * Emotional Stability: 4R, 9
# * Openness to Experiences: 5, 10R
#
# ***Note***: `R` attached indicates reversely-scored item.

# %% [markdown]
# * 1 = Disagree strongly
# * 2 = Disagree moderately
# * 3 = Disagree a little
# * 4 = Neither agree nor disagree
# * 5 = Agree a little
# * 6 = Agree moderately
# * 7 = Agree strongly

# %% [markdown]
# **Adjusted Extroversion Score**: TIPI1 + (7 - TIPI6)
# * Lowest: 0
# * Highest: 14

# %%
data['Extroversion'] = data.apply(lambda row: row.TIPI1 + (7-row.TIPI6), axis=1)

# %%
data.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  familysize  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...           2
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...           4
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...           3
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...           5
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...           4
#
#         major  categorical_age  stress_score  stress_category  anxiety_score  \
# 0         NaN                0            54                5             48
# 1         NaN                0            41                4             31
# 2         NaN                1            31                2             26
# 3     biology                0            30                2             31
# 4  Psychology                1            43                4             54
#
# ...

# %%
ax = sns.countplot(x='Extroversion',data=data)
ax.set_title('Extroversion Score Distribution')
plt.show()

# %% [markdown]
# **Adjusted Agreeableness Score**: (7-TIPI2) + TIPI7
# * Lowest: 0
# * Highest: 14

# %%
data['Agreeableness'] = data.apply(lambda row: row.TIPI7 + (7-row.TIPI2), axis=1)

# %%
ax = sns.countplot(x='Agreeableness',data=data)
ax.set_title('Agreeableness Score Distribution')
plt.show()

# %% [markdown]
# **Adjusted Conscientiousness Score**: TIPI3 + (7-TIPI8)
# * Lowest: 0
# * Highest: 14

# %%
data['Conscientiousness'] = data.apply(lambda row: row.TIPI3 + (7-row.TIPI8), axis=1)

# %%
ax = sns.countplot(x='Conscientiousness',data=data)
ax.set_title('Conscientiousness Score Distribution')
plt.show()

# %% [markdown]
# **Adjusted Emotional Stability Score**: (7-TIPI4)+TIPI9
# * Lowest: 0
# * Highest: 14

# %%
data['Emotional_stability'] = data.apply(lambda row: row.TIPI9 + (7-row.TIPI4), axis=1)

# %%
ax = sns.countplot(x='Emotional_stability',data=data)
ax.set_title('Emotional Stability Score Distribution')
plt.show()

# %% [markdown]
# **Adjusted Openness to Experiences Score**: TIPI5 + (7-TIPI10)
# * Lowest: 0
# * Highest: 14

# %%
data['Openness_to_experience'] = data.apply(lambda row: row.TIPI5 + (7-row.TIPI10), axis=1)

# %%
ax = sns.countplot(x='Openness_to_experience',data=data)
ax.set_title('Openness to experience Stability Score Distribution')
plt.show()

# %% [markdown]
# ## Combine Depression, Anxiety, and Stress and Demographic Info

# %%
data.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  stress_category  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...                5
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...                4
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...                2
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...                2
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...                4
#
#    anxiety_score  anxiety_category  depression_score  depression_category  \
# 0             48                 5                41                    4
# 1             31                 4                38                    4
# 2             26                 3                53                    5
# 3             31                 4                30                    3
# 4             54                 5                46                    5
#
# ...

# %%
np.array(data.columns)
# Out:
# array(['Q1A', 'Q1I', 'Q1E', 'Q2A', 'Q2I', 'Q2E', 'Q3A', 'Q3I', 'Q3E',
#        'Q4A', 'Q4I', 'Q4E', 'Q5A', 'Q5I', 'Q5E', 'Q6A', 'Q6I', 'Q6E',
#        'Q7A', 'Q7I', 'Q7E', 'Q8A', 'Q8I', 'Q8E', 'Q9A', 'Q9I', 'Q9E',
#        'Q10A', 'Q10I', 'Q10E', 'Q11A', 'Q11I', 'Q11E', 'Q12A', 'Q12I',
#        'Q12E', 'Q13A', 'Q13I', 'Q13E', 'Q14A', 'Q14I', 'Q14E', 'Q15A',
#        'Q15I', 'Q15E', 'Q16A', 'Q16I', 'Q16E', 'Q17A', 'Q17I', 'Q17E',
#        'Q18A', 'Q18I', 'Q18E', 'Q19A', 'Q19I', 'Q19E', 'Q20A', 'Q20I',
#        'Q20E', 'Q21A', 'Q21I', 'Q21E', 'Q22A', 'Q22I', 'Q22E', 'Q23A',
#        'Q23I', 'Q23E', 'Q24A', 'Q24I', 'Q24E', 'Q25A', 'Q25I', 'Q25E',
#        'Q26A', 'Q26I', 'Q26E', 'Q27A', 'Q27I', 'Q27E', 'Q28A', 'Q28I',
#        'Q28E', 'Q29A', 'Q29I', 'Q29E', 'Q30A', 'Q30I', 'Q30E', 'Q31A',
#        'Q31I', 'Q31E', 'Q32A', 'Q32I', 'Q32E', 'Q33A', 'Q33I', 'Q33E',
#        'Q34A', 'Q34I', 'Q34E', 'Q35A', 'Q35I', 'Q35E', 'Q36A', 'Q36I',
# ...

# %% [markdown]
# ### Depression and Demographics

# %%
g = sns.catplot(y="education", col="depression_category",
                data=data, kind="count",
                height= 4, aspect= 2, col_wrap = 1
               # hue="gender",
               );
g.set_yticklabels(["unknown","less than high school", "high school", "university degree", "graduate degree"])
plt.show()

# %%
g = sns.catplot(x="gender", col="depression_category",
                data=data, kind="count",
                height=4, aspect=.7
               # hue="gender",
               );
g.set_xticklabels(["unknown","male","female","other"])
plt.show()

# %%
g = sns.catplot(y="race", col="depression_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["Asian", "Arab", "Black", "Indigenous Australian", "Native American","White", "Other"])
plt.show()

# %%
g = sns.catplot(y="orientation", col="depression_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["unknown","heterosexual","bisexual","homosexual","asexual","other"])
plt.show()

# %% [markdown]
# Add a comment here: it is not clear since heterosexual population dominates here. Might apply ratios (depression/total) of that category instead of counts.

# %%
g = sns.catplot(y="categorical_age", col="depression_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["Less than 16", "Between 16 and 32","Betwwen 32 and 48", "Between 48 and 64", "Above 64"])
plt.show()

# %% [markdown]
# ### Anxiety and Demographics

# %%
g = sns.catplot(y="education", col="anxiety_category",
                data=data, kind="count",
                height= 4, aspect= 2, col_wrap = 1
               # hue="gender",
               );
g.set_yticklabels(["unknown","less than high school", "high school", "university degree", "graduate degree"])
plt.show()

# %%
g = sns.catplot(x="gender", col="anxiety_category",
                data=data, kind="count",
                height=4, aspect=.7
               # hue="gender",
               );
g.set_xticklabels(["unknown","male","female","other"])
plt.show()

# %%
g = sns.catplot(y="race", col="anxiety_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["Asian", "Arab", "Black", "Indigenous Australian", "Native American","White", "Other"])
plt.show()

# %%
g = sns.catplot(y="orientation", col="anxiety_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["unknown","heterosexual","bisexual","homosexual","asexual","other"])
plt.show()

# %%
g = sns.catplot(y="categorical_age", col="anxiety_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["Less than 16", "Between 16 and 32","Betwwen 32 and 48", "Between 48 and 64", "Above 64"])
plt.show()

# %% [markdown]
# ### Stress and Demographics

# %%
g = sns.catplot(y="education", col="stress_category",
                data=data, kind="count",
                height= 4, aspect= 2, col_wrap = 1
               # hue="gender",
               );
g.set_yticklabels(["unknown","less than high school", "high school", "university degree", "graduate degree"])
plt.show()

# %%
g = sns.catplot(x="gender", col="stress_category",
                data=data, kind="count",
                height=4, aspect=.7
               # hue="gender",
               );
g.set_xticklabels(["unknown","male","female","other"])
plt.show()

# %%
g = sns.catplot(y="race", col="stress_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["Asian", "Arab", "Black", "Indigenous Australian", "Native American","White", "Other"])
plt.show()

# %%
g = sns.catplot(y="orientation", col="stress_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["unknown","heterosexual","bisexual","homosexual","asexual","other"])
plt.show()

# %%
g = sns.catplot(y="categorical_age", col="stress_category",
                data=data, kind="count",
                height=4, aspect= 1.5, col_wrap = 2
               # hue="gender",
               );
g.set_yticklabels(["Less than 16", "Between 16 and 32","Betwwen 32 and 48", "Between 48 and 64", "Above 64"])
plt.show()

# %% [markdown]
# ## Comorbidity of DASS

# %%
data_cat = pd.DataFrame(data, columns = 
                        ['race',
                         'categorical_age','urban',
                         'orientation','gender','education',
                         'anxiety_category',
                         'stress_category',
                         'depression_category'])
data_cat.head()
# Out:
#    race  categorical_age  urban  orientation  gender  education  \
# 0    10                0      3            1       2          2
# 1    70                0      3            0       2          2
# 2    60                1      3            3       2          2
# 3    70                0      3            5       2          1
# 4    10                1      2            1       2          3
#
#    anxiety_category  stress_category  depression_category
# 0                 5                5                    4
# 1                 4                4                    4
# 2                 3                2                    5
# 3                 4                2                    3
# 4                 5                4                    5

# %%
race_mapping = {10: "Asian", 20:"Arab", 30:"Black", 40:"Indigenous Australian", 
                50:"Native American", 60:"White", 70:"Other"}
data_cat['race'] = data_cat['race'].map(race_mapping)

# %%
data_cat.head()
# Out:
#     race  categorical_age  urban  orientation  gender  education  \
# 0  Asian                0      3            1       2          2
# 1  Other                0      3            0       2          2
# 2  White                1      3            3       2          2
# 3  Other                0      3            5       2          1
# 4  Asian                1      2            1       2          3
#
#    anxiety_category  stress_category  depression_category
# 0                 5                5                    4
# 1                 4                4                    4
# 2                 3                2                    5
# 3                 4                2                    3
# 4                 5                4                    5

# %%
sns.scatterplot(x="anxiety_category",y='stress_category',hue='race',data=data_cat)

# %%
data_cat.shape
# Out:
# (39775, 9)

# %%
data_cat.dtypes
# Out:
# race                   object
# categorical_age         int64
# urban                   int64
# orientation             int64
# gender                  int64
# education               int64
# anxiety_category        int64
# stress_category         int64
# depression_category     int64
# dtype: object

# %%
data['race'].value_counts()
# Out:
# 10    23106
# 60    10659
# 70     4832
# 30      603
# 20      333
# 50      220
# 40       22
# Name: race, dtype: int64

# %%
ax = sns.catplot(x='anxiety_category',y='depression_category',hue='race',kind='point',data=data_cat)
ax.fig.autofmt_xdate()

# %%
ax = sns.catplot(x='stress_category',y='depression_category',hue='race',kind='point',data=data_cat)
ax.fig.autofmt_xdate()

# %%
ax = sns.catplot(x='anxiety_category',y='stress_category',hue='race',kind='point',data=data_cat)
ax.fig.autofmt_xdate()

# %%
orientation_mapping = {1:"Heterosexual", 2:"Bisexual", 3:"Homosexual", 4:"Asexual", 5:"Other"}
data_cat['orientation'] = data_cat['orientation'].map(orientation_mapping)

# %%
ax = sns.catplot(x='anxiety_category',y='depression_category',hue='orientation',kind='point',data=data_cat)
ax.fig.autofmt_xdate()

# %%
ax = sns.catplot(x='stress_category',y='depression_category',hue='orientation',kind='point',data=data_cat)
ax.fig.autofmt_xdate()

# %%
ax = sns.catplot(x='anxiety_category',y='stress_category',hue='orientation',kind='point',data=data_cat)
ax.fig.autofmt_xdate()

# %% [markdown]
# **Current Problem**: want to show the density of high anxiety, high depression, BUT now we can only see 1 point in the scatterplot since all the data are (5,5).

# %%
anx_dep = pd.crosstab(data_cat.anxiety_category,data_cat.depression_category)

# %%
anx_dep
# Out:
# depression_category     1     2     3     4     5
# anxiety_category
# 1                    5716  1255  1334   692   731
# 2                     923   461   661   355   364
# 3                    1334  1049  1923  1253  1489
# 4                     543   593  1541  1472  1964
# 5                     340   428  1620  2705  9029

# %%
sns.heatmap(anx_dep, annot=True,cmap="YlGnBu")

# %%
anx_str = pd.crosstab(data_cat.anxiety_category,data_cat.stress_category)

# %%
sns.heatmap(anx_str, annot=True,cmap="YlGnBu")

# %%
dep_str = pd.crosstab(data_cat.depression_category,data_cat.stress_category)

# %%
sns.heatmap(dep_str, annot=True,cmap="YlGnBu")

# %%
race_anx = pd.crosstab(data_cat.anxiety_category, data_cat.race)

# %%
race_anx
# Out:
# race              Arab  Asian  Black  Indigenous Australian  Native American  \
# anxiety_category
# 1                   72   5214    184                      5               40
# 2                   23   1616     52                      1               10
# 3                   48   4208     91                      3               24
# 4                   49   3672     74                      3               35
# 5                  141   8396    202                     10              111
#
# race              Other  White
# anxiety_category
# 1                  1147   3066
# 2                   327    735
# 3                   839   1835
# 4                   734   1546
# 5                  1785   3477

# %%
race_anx.columns
# Out:
# Index(['Arab', 'Asian', 'Black', 'Indigenous Australian', 'Native American',
#        'Other', 'White'],
#       dtype='object', name='race')

# %%
race_anx['Arab'].sum()
# Out:
# 333
